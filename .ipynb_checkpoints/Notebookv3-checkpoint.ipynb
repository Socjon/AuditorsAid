# %% [markdown]
# # Predicting the IRS 501(c)
# Jon Tyler

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Predicting-the-IRS-501(c)" data-toc-modified-id="Predicting-the-IRS-501(c)-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Predicting the IRS 501(c)</a></span><ul class="toc-item"><li><span><a href="#Obtaining-the-Data" data-toc-modified-id="Obtaining-the-Data-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Obtaining the Data</a></span></li><li><span><a href="#Data-cleaning" data-toc-modified-id="Data-cleaning-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Data cleaning</a></span><ul class="toc-item"><li><span><a href="#Column-Description" data-toc-modified-id="Column-Description-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Column Description</a></span></li><li><span><a href="#Scrub-1" data-toc-modified-id="Scrub-1-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Scrub 1</a></span></li><li><span><a href="#Scrub-2" data-toc-modified-id="Scrub-2-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Scrub 2</a></span></li><li><span><a href="#Breaking-into-subsets" data-toc-modified-id="Breaking-into-subsets-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>Breaking into subsets</a></span></li></ul></li><li><span><a href="#Explore" data-toc-modified-id="Explore-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Explore</a></span></li><li><span><a href="#Data-Sets" data-toc-modified-id="Data-Sets-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Data Sets</a></span><ul class="toc-item"><li><span><a href="#Full" data-toc-modified-id="Full-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Full</a></span></li><li><span><a href="#Post---1995" data-toc-modified-id="Post---1995-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Post - 1995</a></span></li><li><span><a href="#Downsized" data-toc-modified-id="Downsized-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Downsized</a></span></li></ul></li></ul></li><li><span><a href="#MODELS" data-toc-modified-id="MODELS-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>MODELS</a></span><ul class="toc-item"><li><span><a href="#Decision-Tree" data-toc-modified-id="Decision-Tree-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Decision Tree</a></span><ul class="toc-item"><li><span><a href="#Decision-Tree-Full" data-toc-modified-id="Decision-Tree-Full-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Decision Tree Full</a></span></li><li><span><a href="#Decision-Tree-Post" data-toc-modified-id="Decision-Tree-Post-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Decision Tree Post</a></span></li><li><span><a href="#Decision-Tree-Downsized" data-toc-modified-id="Decision-Tree-Downsized-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Decision Tree Downsized</a></span></li></ul></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Random Forest</a></span><ul class="toc-item"><li><span><a href="#Random-Forest-Full" data-toc-modified-id="Random-Forest-Full-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Random Forest Full</a></span></li><li><span><a href="#Random-Forest-Post" data-toc-modified-id="Random-Forest-Post-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Random Forest Post</a></span></li><li><span><a href="#Random-Forest-Downsized" data-toc-modified-id="Random-Forest-Downsized-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Random Forest Downsized</a></span></li></ul></li><li><span><a href="#XGBoost" data-toc-modified-id="XGBoost-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>XGBoost</a></span><ul class="toc-item"><li><span><a href="#XGB-Full" data-toc-modified-id="XGB-Full-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>XGB Full</a></span></li><li><span><a href="#XGB-Post" data-toc-modified-id="XGB-Post-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>XGB Post</a></span></li><li><span><a href="#XGB-Down" data-toc-modified-id="XGB-Down-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>XGB Down</a></span></li></ul></li></ul></li><li><span><a href="#Results" data-toc-modified-id="Results-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Results</a></span></li></ul></div>

# %% [markdown]
# ## Obtaining the Data
#
# "The IRS maintains several important nonprofit databases to track the current population of exempt organizations, their annual 990 filings, and organizations that have closed. This data has been released in formats that are not always easy to use - ASCII text files, json files, and XML queries. In order to make the data accessible to the research community, [Jesse Lecy and a team](https://lecy.github.io/Open-Data-for-Nonprofit-Research/) have created scripts to download data from IRS websites, clean and process it, and export into familiar formats (CSV, Stata, SPSS, etc.)." [Open Data for Nonprofit Research](https://github.com/lecy/Open-Data-for-Nonprofit-Research)
#
# It is from the hard work in those notebooks that allowed me to explore this data set.
# ___
#
# ___
#
# The IRS breaks down non-profit organizations into subgroups based on the type of work the organizations does. There was a change in that coding guideline in 1995 where a new system was adopted - National Taxonomy of Exempt Entities (NTEE) Codes. I plan to predict these categories (seen below) given other characteristics from their submitted tax forms.

# %% [markdown]
# NTEE Category | Definition
# ---------|---------------
# A           |          Arts, Culture, and Humanities
# B           |          Education
# C           |          Environmental Quality, Protection, and Beautification
# D           |          Animal-Related
# E           |          Health
# F           |          Mental Health, Crisis Intervention
# G           |          Diseases, Disorders, Medical Disciplines
# H           |          Medical Research
# I           |          Crime, Legal Related
# J           |          Employment, Job Related
# K           |          Food, Agriculture, and Nutrition
# L           |          Housing, Shelter
# M           |          Public Safety
# N           |          Recreation, Sports, Leisure, Athletics
# O           |          Youth Development
# P           |          Human Services - Multipurpose and Other
# Q           |          International, Foreign Affairs, and National Security
# R           |          Civil Rights, Social Action, Advocacy
# S           |          Community Improvement, Capacity Building
# T           |          Philanthropy, Voluntarism, and Grantmaking Foundations
# U           |          Science and Technology Research Institutes, Services
# V           |          Social Science Research Institutes, Services
# W           |          Public, Society Benefit - Multipurpose and Other
# X           |          Religion Related, Spiritual Development
# Y           |          Mutual/Membership Benefit Organizations, Other
# Z           |          Unknown

# %% [markdown]
# [Open Data for Nonprofit Research](https://github.com/lecy/Open-Data-for-Nonprofit-Research) produced a R code to query, pull, and save the IRS data. Please see [this](Data_pull_in_R.ipynb) notebook for further details.

# %% [markdown]
# ## Data cleaning
#
# Following the normal routine, import the dataset and make sure it was read correctly.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df = pd.read_csv('./data/BusinessMasterFile.csv')
df.head()
# Out:
#       EIN                                              NAME  ICO  \
# 0   19818                      PALMER SECOND BAPTIST CHURCH  NaN
# 1   29215                               ST GEORGE CATHEDRAL  NaN
# 2  587764                              IGLESIA BETHESDA INC  NaN
# 3  635913  MINISTERIO APOSTOLICO JESUCRISTO ES EL SENOR INC  NaN
# 4  765634                        MERCY CHAPEL INTERNATIONAL  NaN
#
#                          STREET          CITY STATE         ZIP  GROUP  \
# 0             1050 THORNDIKE ST        PALMER    MA  01069-1507   3125
# 1                523 E BROADWAY  SOUTH BOSTON    MA  02127-4415   2365
# 2                157 ANDOVER ST        LOWELL    MA  01852-2348      0
# 3                  454 ESSEX ST      LAWRENCE    MA  01840-1242      0
# 4  75 MORTON VILLAGE DR APT 408      MATTAPAN    MA  02126-2433      0
#
#    SUBSECTION  AFFILIATION  ...  ASSET_AMT  INCOME_AMT  REVENUE_AMT  NTEE_CD  \
# 0           3            9  ...        NaN         NaN          NaN      NaN
# 1           3            9  ...        NaN         NaN          NaN      NaN
# 2           3            3  ...        NaN         NaN          NaN      X21
# 3           3            3  ...        NaN         NaN          NaN      X21
# 4           3            3  ...        NaN         NaN          NaN      X20
#
#    SORT_NAME  RULEYEAR  LEVEL4  ACT1  ACT2  ACT3
# 0       3514      1955     NaN   100   0.0   0.0
# 1        NaN      1972     NaN   100   0.0   0.0
# 2        NaN      2004       X     0   NaN   NaN
# 3        NaN      2004       X     0   NaN   NaN
# 4        NaN      2004       X     0   NaN   NaN
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1691200 entries, 0 to 1691199
# Data columns (total 33 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   EIN               int64
#  1   NAME              object
#  2   ICO               object
#  3   STREET            object
#  4   CITY              object
#  5   STATE             object
#  6   ZIP               object
#  7   GROUP             int64
#  8   SUBSECTION        int64
#  9   AFFILIATION       int64
#  10  CLASSIFICATION    int64
#  11  RULING            int64
#  12  DEDUCTIBILITY     int64
#  13  FOUNDATION        int64
#  14  ACTIVITY          int64
#  15  ORGANIZATION      int64
#  16  STATUS            int64
#  17  TAX_PERIOD        float64
#  18  ASSET_CD          int64
#  19  INCOME_CD         int64
#  20  FILING_REQ_CD     int64
#  21  PF_FILING_REQ_CD  int64
#  22  ACCT_PD           int64
#  23  ASSET_AMT         float64
#  24  INCOME_AMT        float64
#  25  REVENUE_AMT       float64
#  26  NTEE_CD           object
#  27  SORT_NAME         object
#  28  RULEYEAR          int64
#  29  LEVEL4            object
#  30  ACT1              int64
#  31  ACT2              float64
#  32  ACT3              float64
# dtypes: float64(6), int64(18), object(9)
# memory usage: 425.8+ MB

# %%
df.columns
# Out:
# Index(['EIN', 'NAME', 'ICO', 'STREET', 'CITY', 'STATE', 'ZIP', 'GROUP',
#        'SUBSECTION', 'AFFILIATION', 'CLASSIFICATION', 'RULING',
#        'DEDUCTIBILITY', 'FOUNDATION', 'ACTIVITY', 'ORGANIZATION', 'STATUS',
#        'TAX_PERIOD', 'ASSET_CD', 'INCOME_CD', 'FILING_REQ_CD',
#        'PF_FILING_REQ_CD', 'ACCT_PD', 'ASSET_AMT', 'INCOME_AMT', 'REVENUE_AMT',
#        'NTEE_CD', 'SORT_NAME', 'RULEYEAR', 'LEVEL4', 'ACT1', 'ACT2', 'ACT3'],
#       dtype='object')

# %% [markdown]
# ### Column Description
#
# The following information is taken from official IRS documentation of this dataset. This documentation can be found [here](irs_jan_2010.pdf)
#
# | Column Name | Contents |
# |-------------|----------|
# | EIN |Employer Identification Number (EIN)|
# | NAME |Primary Name of Organization |
# | ICO  | In Care of Name|
# | STREET | Street Address|
# | CITY | City |
# | STATE | State |
# | ZIP | Zip Code |
# | GROUP |Group Exemption Number |
# |SUBSECTION | Subsection Code |
# | AFFILIATION | Affiliation Code(s) |
# | CLASSIFICATION | Classification Code(s)|
# | RULING | Ruling Date |
# | DEDUCTIBILITY | Deductibility Code |
# | FOUNDATION | Foundation Code |
# |  ACTIVITY | Activity Codes |
# | ORGANIZATION | Organization Code |
# | STATUS | Exempt Organization Status Code |
# | TAX_PERIOD | Tax Period |
# |ASSET_CD           |          Asset Code|
# |  INCOME_CD           |          Income Code|
# | FILING_REQ_CD     |          Filing Requirement Code |
# |  ACCT_PD           |          Accounting Period|
# | ASSET_AMT           |          Asset Amount |
# | INCOME_AMT           |          Income Amount (includes negative sign if amount is negative) |
# | REVENUE_AMT           |          Form 990 Revenue Amount (includes negative sign if amount is negative) |
# | NTEE_CD National           |          Taxonomy of Exempt Entities (NTEE) Code |
# SORT_NAME           |          Sort Name (Secondary Name Line) |
#
# There are a few additional columns that were created during the retrieval of the dataset.
# - The variable `ACTIVITIES` consists of three separate 3-digit activity codes. These were split these into separate variables: `ACT1`, `ACT2`, `ACT3`.
# - `LEVEL4` broke down the entries with the `NTEE` coding into the major category.
# - `RULEYEAR` split out the year from `RULING` which was formatted as YYYY-MM

# %% [markdown]
# Now lets investigate missing values.

# %%
import missingno as msno
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The non-shaded area indicate missing values. By visualizing the data this way, you can quickly identify if there are patterns to what is missing in the data.

# %%
msno.heatmap(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# This heatmap correlates missing data with other missing data. Just as the graph above indicated, there is correlation between the different levels `ACT`. Also, as expected, a perfect correlation of missing values from `LEVEL4` and `NTEE_CD`.
#
# There is a clear pattern in the missing values from `REVENUE_AMT`, `ASSET_AMT`, `INCOME_AMT`, and `TAX_PERIOD`. So lets take a closer look at those columns.

# %%
print(df.REVENUE_AMT.value_counts()[:5])
print('--------------------------------')
print(df.REVENUE_AMT.isna().value_counts())
# Out:
# 0.0        688791
# 1000.0        296
# 500.0         221
# 5000.0        215
# 100.0         214
# 1.0           204
# 10000.0       185
# 2000.0        163
# 3000.0        133
# 200.0         129
# 1500.0        122
# 2500.0        116
# 2.0           105
# 6000.0        103
# 300.0          99
# 5.0            98
# Name: REVENUE_AMT, dtype: int64
# --------------------------------
# False    1212088
# True      479112
# Name: REVENUE_AMT, dtype: int64

# %%
print(df.ASSET_AMT.value_counts()[:5])
print('--------------------------------')
print(df.ASSET_AMT.isna().sum())
print('--------------------------------')
print(df.ASSET_CD.value_counts()[:5])
print('--------------------------------')
print(df.ASSET_CD.isna().sum())
# Out:
# 0.0        677902
# 1.0         15623
# 100.0         285
# 1000.0        217
# 500.0         191
# 200.0         120
# 2000.0        108
# 5000.0        103
# 10.0          101
# 50.0           90
# 300.0          83
# 1500.0         81
# 150.0          73
# 10000.0        69
# 25.0           69
# 5.0            67
# Name: ASSET_AMT, dtype: int64
# --------------------------------
# 368826
# --------------------------------
# 0    1032113
# 4     169004
# 3     123873
# 6     101784
# 1      80491
# Name: ASSET_CD, dtype: int64
# --------------------------------
# 0

# %% [markdown]
# `ASSET_AMT` is continuous data, rather than the coded data in `ASSET_CD`, so I will keep the amounts reported over the IRS prebinned values. I can alter it myself if need be.
#
# Through further look the the IRS [documentation](irs_jan_2010.pdf) of these columns, there seems to be some discrepancy in values from the coded and the reported, which makes my decision to drop the `_CD` versions of Income and Asset.

# %% [markdown]
# ### Scrub 1
#
# With over 1.6 million rows, this is large dataset. Starting things off, first drop the columns that I will not be using.
#
# With my target going to be the Major Group the non-profit belongs to, I will drop the `LEVEL4` column as well. This is to ensure integrity of my models working or failing based on my own work, rather than relying on others.
#
# I am planning to break the dataset into subsets:
# - Full dataset, recoding the old `ACTIVITY` codes into the NTEE Major Groups
# - Post-1995, only the IRS coded entities
# - Downsized portion, specifically with equal class sizes

# %%
df.drop(['ICO', 
         'RULING',
         'ACT1',
         'ACT2', 
         'ACT3', 
         'ASSET_CD', 
         'INCOME_CD', 
         'LEVEL4', 
         'TAX_PERIOD'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1691200 entries, 0 to 1691199
# Data columns (total 24 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   EIN               int64
#  1   NAME              object
#  2   STREET            object
#  3   CITY              object
#  4   STATE             object
#  5   ZIP               object
#  6   GROUP             int64
#  7   SUBSECTION        int64
#  8   AFFILIATION       int64
#  9   CLASSIFICATION    int64
#  10  DEDUCTIBILITY     int64
#  11  FOUNDATION        int64
#  12  ACTIVITY          int64
#  13  ORGANIZATION      int64
#  14  STATUS            int64
#  15  FILING_REQ_CD     int64
#  16  PF_FILING_REQ_CD  int64
#  17  ACCT_PD           int64
#  18  ASSET_AMT         float64
#  19  INCOME_AMT        float64
#  20  REVENUE_AMT       float64
#  21  NTEE_CD           object
#  22  SORT_NAME         object
#  23  RULEYEAR          int64
# dtypes: float64(3), int64(14), object(7)
# memory usage: 309.7+ MB

# %% [markdown]
# Now lets figure out something to do with the missing values within the columns I kept.

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is a clear pattern of missing values from `ASSET_AMT`,`INCOME_AMT`, and `REVENUE_AMT`. I will drop values from one column, extending down the rows and then will recheck the patterns.

# %%
df = df.dropna(subset=['ASSET_AMT']) #Drop based on the subset column or columns
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ~370,000 entries were removed.

# %%
df.isna().sum()
# Out:
# EIN                      0
# NAME                     0
# STREET                   2
# CITY                     0
# STATE                 1062
# ZIP                      0
# GROUP                    0
# SUBSECTION               0
# AFFILIATION              0
# CLASSIFICATION           0
# DEDUCTIBILITY            0
# FOUNDATION               0
# ACTIVITY                 0
# ORGANIZATION             0
# STATUS                   0
# FILING_REQ_CD            0
# PF_FILING_REQ_CD         0
# ACCT_PD                  0
# ASSET_AMT                0
# INCOME_AMT               0
# REVENUE_AMT         110286
# NTEE_CD             451552
# SORT_NAME           965875
# RULEYEAR                 0
# dtype: int64

# %% [markdown]
# The last 100K from `REVENUE_AMT` will be dropped as well. I will combine the `SORT_NAME` column with the `NAME` column since they both come from the same field, just a different line. `NTEE_CD` will be addressed seperately as well.

# %%
df = df.dropna(subset=['REVENUE_AMT'])

# %%
df.isna().sum()
# Out:
# EIN                      0
# NAME                     0
# STREET                   2
# CITY                     0
# STATE                  940
# ZIP                      0
# GROUP                    0
# SUBSECTION               0
# AFFILIATION              0
# CLASSIFICATION           0
# DEDUCTIBILITY            0
# FOUNDATION               0
# ACTIVITY                 0
# ORGANIZATION             0
# STATUS                   0
# FILING_REQ_CD            0
# PF_FILING_REQ_CD         0
# ACCT_PD                  0
# ASSET_AMT                0
# INCOME_AMT               0
# REVENUE_AMT              0
# NTEE_CD             415581
# SORT_NAME           868547
# RULEYEAR                 0
# dtype: int64

# %% [markdown]
# Creating the full name of the group or organization, then dropping the excess columns

# %%
df.SORT_NAME = df.SORT_NAME.fillna(value = '') #Replaces np.NaN values with something else, string + np.NaN = np.NaN
df['NAME_FULL'] = df.NAME + ' ' + df.SORT_NAME #New column
df.drop(['NAME', 'SORT_NAME'], axis=1, inplace=True) #Getting rid of the old
df.head()
# Out:
#          EIN                 STREET          CITY STATE         ZIP  GROUP  \
# 12  10002847             PO BOX 126    HULLS COVE    ME  04644-0126      0
# 13  10011694  30 SAMUEL PRESCOTT DR          STOW    MA  01775-1167      0
# 14  10015091              PO BOX 13  CEDAR KNOLLS    NJ  07927-0013      0
# 15  10017496             PO BOX 534   YORK HARBOR    ME  03911-0534      0
# 16  10018555         81 COLLEGE AVE         ORONO    ME  04473-4210    287
#
#     SUBSECTION  AFFILIATION  CLASSIFICATION  DEDUCTIBILITY  ...  STATUS  \
# 12           3            3            1000              1  ...       1
# 13           3            3            1000              1  ...       1
# 14           3            3            1000              1  ...       1
# 15           3            3            2000              1  ...       1
# 16           7            9            1000              2  ...       1
#
#     FILING_REQ_CD  PF_FILING_REQ_CD  ACCT_PD  ASSET_AMT  INCOME_AMT  \
# 12              2                 0       12        0.0         0.0
# 13              2                 0       12        0.0         0.0
# 14              1                 0       12    62462.0    140685.0
# 15              1                 0       12   233819.0    180773.0
# 16              2                 0       12        0.0         0.0
#
#     REVENUE_AMT  NTEE_CD  RULEYEAR  \
# 12          0.0      A80      2000
# 13          0.0      S19      2015
# 14     140685.0      N64      2012
# 15     127013.0      NaN      1993
# 16          0.0      NaN      1941
#
#                                             NAME_FULL
# 12               HULLS COVE NEIGHBORHOOD ASSOCIATION
# 13              MASSACHUSETTS MODERATORS ASSOCIATION
# 14                           HANOVER SOCCER CLUB INC
# 15                    AGAMENTICUS YACHT CLUB OF YORK
# 16  ALPHA TAU OMEGA FRATERNITY BETA UPSILION MAINE...
#
# [5 rows x 23 columns]

# %%
df.isna().sum()
# Out:
# EIN                      0
# STREET                   2
# CITY                     0
# STATE                  940
# ZIP                      0
# GROUP                    0
# SUBSECTION               0
# AFFILIATION              0
# CLASSIFICATION           0
# DEDUCTIBILITY            0
# FOUNDATION               0
# ACTIVITY                 0
# ORGANIZATION             0
# STATUS                   0
# FILING_REQ_CD            0
# PF_FILING_REQ_CD         0
# ACCT_PD                  0
# ASSET_AMT                0
# INCOME_AMT               0
# REVENUE_AMT              0
# NTEE_CD             415581
# RULEYEAR                 0
# NAME_FULL                0
# dtype: int64

# %% [markdown]
# My target is going to `ACTIVITY`/`NTEE_CD`. The values in `ACTIVITY` are 9 characters long, each set of three indicating what kind of the organization it is. The codes used can be found [here](irs_jan_2010.pdf). There are some that needed more than one set of three to define their organization, others only have one. I plan to use only the first activity code, with the idea it would be the primary category. Also I have to keep in mind, there are groups that could apply to different targets based on all three activity codes.
#
# It is stated by [Open Data for Nonprofit Research](https://github.com/lecy/Open-Data-for-Nonprofit-Research) the data itself is not that clean. Effort will be made to tidy it up.
#
# The NTEE_CD code was introduced to replace the three digit code in 1995. I will make my own mapping from the old system to the new system. Lets take look at what I have at hand first.

# %%
df.loc[(df.NTEE_CD.notna()) & (df.ACTIVITY == 0)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 604936 entries, 12 to 1691194
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   EIN               604936 non-null  int64
#  1   STREET            604936 non-null  object
#  2   CITY              604936 non-null  object
#  3   STATE             604403 non-null  object
#  4   ZIP               604936 non-null  object
#  5   GROUP             604936 non-null  int64
#  6   SUBSECTION        604936 non-null  int64
#  7   AFFILIATION       604936 non-null  int64
#  8   CLASSIFICATION    604936 non-null  int64
#  9   DEDUCTIBILITY     604936 non-null  int64
#  10  FOUNDATION        604936 non-null  int64
#  11  ACTIVITY          604936 non-null  int64
#  12  ORGANIZATION      604936 non-null  int64
#  13  STATUS            604936 non-null  int64
#  14  FILING_REQ_CD     604936 non-null  int64
#  15  PF_FILING_REQ_CD  604936 non-null  int64
#  16  ACCT_PD           604936 non-null  int64
#  17  ASSET_AMT         604936 non-null  float64
#  18  INCOME_AMT        604936 non-null  float64
#  19  REVENUE_AMT       604936 non-null  float64
#  20  NTEE_CD           604936 non-null  object
#  21  RULEYEAR          604936 non-null  int64
#  22  NAME_FULL         604936 non-null  object
# dtypes: float64(3), int64(14), object(6)
# memory usage: 110.8+ MB

# %%
df.NTEE_CD.notna().sum()
# Out:
# 796507

# %%
df.NTEE_CD.isna().sum()
# Out:
# 415581

# %%
df.ACTIVITY.value_counts()[:10]
# Out:
# 0            648115
# 59000000      12946
# 907908000     11636
# 59035000      11596
# 205000000     10981
# 36000000      10129
# 263264279      9497
# 200000000      9436
# 319000000      8836
# 59319000       8748
# Name: ACTIVITY, dtype: int64

# %% [markdown]
# There is something wrong with the above `.value_counts()`.
#
# The Activity Codes provided by the IRS have leading zeroes. Since there wasn't an attempt to control for it them when orginally reading the files, I want further to investigate if the `ACTIVITY` lines contain 9 characters. If they don't, I will adjust them accordingly.

# %%
temp = df.ACTIVITY

# %%
length = []
for x in temp:
    length.append(len(str(x)))
pd.Series(length).value_counts()
# Out:
# 1    648115
# 9    389701
# 8    163953
# 7     10319
# dtype: int64

# %% [markdown]
# As expected, adjustments are need. Make a small function that will adjust the `ACTIVITY` input to match the 9 character length expected.

# %%
def adj_len(num):
    string = str(num)
    
    if len(string) >= 7:
        
        if len(string) == 9:
            return int(string[0:3])
        if len(string) == 8:
            return int(string[0:2])
        if len(string) == 7:
            return int(string[0:1])
    else:
        return num

# %%
print(f'Produced: {adj_len(123456789)} Expected: 123')
print('-----------------')
print(f'Produced: {adj_len(42)} Expected: 42')
print('-----------------')
print(f'Produced: {adj_len(12345678)} Expected: 12')
print('-----------------')
print(f'Produced: {adj_len(1234567)} Expected: 1')
print('-----------------')
# Out:
# Produced: 123 Expected: 123
# -----------------
# Produced: 42 Expected: 42
# -----------------
# Produced: 12 Expected: 12
# -----------------
# Produced: 1 Expected: 1
# -----------------

# %%
def code_NTEE_V1(y):
    
    x = adj_len(y)
    
    list_a =list(range(60,120))
    list_b =list(range(30,60)) + [540, 914]
    list_c =list(range(350,380)) + [529]
    list_d =[913]
    list_e =list(range(150,180)) + [531] + list(range(541,544))
    list_f = []
    list_g = []
    list_h = []
    list_i =list(range(460,466)) + [406, 526, 527, 528]
    list_j =list(range(120,150)) + list(range(200,230)) + [920]
    list_k =list(range(230,250)) + [916]
    list_l =list(range(380,400)) + [401]
    list_m =[902]
    list_n =list(range(280,320))
    list_o =list(range(320,350))
    list_p =list(range(563,576)) + [917, 918]
    list_q =list(range(510,514)) + [518, 519, 520, 522, 910, 911, 912]
    list_r =list(range(430,450)) + list(range(480,510)) + [261, 405, 481, 482, 534, 535, 924]
    list_s =list(range(408,430)) + [404, 524, 533, 903, 919, 921]
    list_t =list(range(600,604)) + list(range(560,563))
    list_u =list(range(180,200)) 
    list_v = []
    list_w =list(range(250,253)) + list(range(536,540)) + list(range(905,909)) + [262, 263, 400, 402, 403, 407, 514, 515, 516, 521, 523, 525, 530 , 532, 559, 915]
    list_x =list(range(1,30)) + [517]
    list_y =list(range(264,280)) + [253, 254, 259, 260, 900, 901, 922]
    list_z = []

    if x in list_a:
        return 'A'
    if x in list_b:
        return 'B'
    if x in list_c:
        return 'C'
    if x in list_d:
        return 'D'
    if x in list_e:
        return 'E'
    if x in list_f:
        return 'F'
    if x in list_g:
        return 'G'
    if x in list_h:
        return 'H'
    if x in list_i:
        return 'I'
    if x in list_j:
        return 'J'
    if x in list_k:
        return 'K'
    if x in list_l:
        return 'L' 
    if x in list_m:
        return 'M'
    if x in list_n:
        return 'N'
    if x in list_o:
        return 'O'
    if x in list_p:
        return 'P'
    if x in list_q:
        return 'Q'
    if x in list_r:
        return 'R'
    if x in list_s:
        return 'S'
    if x in list_t:
        return 'T'
    if x in list_u:
        return 'U'
    if x in list_v:
        return 'V'
    if x in list_w:
        return 'W'
    if x in list_x:
        return 'X'
    if x in list_y:
        return 'Y'
    if x in list_z:
        return 'Z'
    else:
        trouble.append(x)

# %% [markdown]
# Now for create a quick tester set to run through my functions.

# %%
small = df[:200]

# %%
print(code_NTEE_V1(205000000))
# Out:
# J

# %% [markdown]
# Test something with a leading zero, or an `ACTIVITY` that does not have 9 characters

# %%
trouble = [] #Within my small data set, any codes that don't have a new label
small.ACTIVITY.apply(code_NTEE_V1)
print(set(trouble))
print(len(trouble))
# Out:
# {0, 994, 995, 999, 927}
# 18

# %% [markdown]
# With the quick check, there are codes that were not coded. This was to be expected. Within `trouble`, none of these are defined by the IRS. I suspect this set to grown once applied to the larger dataset.
#
# Within the process, I will update the master list with proper categorizations through out. The mapping will be adjusted accordingly. Please see the IRS documentation if further review is desired.

# %% [markdown]
# Before applying the function to the entire dataset, lets take care of the subset of rows that will not have any targets variable at all.

# %%
df.NTEE_CD.isna().sum()
# Out:
# 415581

# %%
print(df[(df.NTEE_CD.isna()) & (df.ACTIVITY == 0)].shape)
df[(df.NTEE_CD.isna()) & (df.ACTIVITY == 0)].head()
# Out:
# (43179, 23)
#           EIN                STREET        CITY STATE         ZIP  GROUP  \
# 32   10027415            1 TUFTS RD     BELFAST    ME  04915-7513    275
# 49   10055140      10 LITCHFIELD RD   HALLOWELL    ME  04347-1109      0
# 78   10114110  150 CAPITOL ST STE 5     AUGUSTA    ME  04330-6858      0
# 300  10216657           952 MAIN ST     SANFORD    ME  04073-3509      0
# 331  10220348            PO BOX 422  FARMINGTON    ME  04938-0422   5930
#
#      SUBSECTION  AFFILIATION  CLASSIFICATION  DEDUCTIBILITY  ...  STATUS  \
# 32            8            9            1000              0  ...       1
# 49           13            3            1000              0  ...       1
# 78            6            0            1000              0  ...       1
# 300           3            3            1200              1  ...       1
# 331           3            9            2000              1  ...       1
#
#      FILING_REQ_CD  PF_FILING_REQ_CD  ACCT_PD  ASSET_AMT  INCOME_AMT  \
# 32               2                 0        3        0.0         0.0
# 49               1                 0        6   546481.0     51568.0
# 78               1                 0        9   142899.0    431279.0
# 300              1                 0        6  1927624.0    624695.0
# 331              2                 0        6        0.0         0.0
#
#      REVENUE_AMT  NTEE_CD  RULEYEAR  \
# 32           0.0      NaN         0
# 49       36162.0      NaN      1976
# 78      431279.0      NaN         0
# 300     538612.0      NaN      1987
# 331          0.0      NaN      2013
#
#                                              NAME_FULL
# 32   ANCIENT FREE & ACCEPTED MASONS OF MAINE 24 BEL...
# 49        HALLOWELL CENTENNIAL BURIAL GROUND ASSN INC
# 78                  MAINE WATER UTILITIES ASSOCIATION
# 300  SANFORD LIBRARY ASSOCIATION LOUIS B GOODALL ME...
# 331  UNIVERSITY OF MAINE SYSTEM INC FRANKLIN COUNTY...
#
# [5 rows x 23 columns]

# %%
before = df.shape

mask = df.index[(df.NTEE_CD.isna()) & (df.ACTIVITY == 0)] #index numbers to drop
df = df.drop(mask)

after = df.shape

print(f'From {before} rows, down to {after} rows')
# Out:
# From (1212088, 23) rows, down to (1168909, 23) rows

# %% [markdown]
# Finally, lets apply our `code_NTEE_V1` function to our dataset. Since there were codes that were no already defined, lets just collect a list of them and then update a new version of my function with those values.

# %%
trouble = [] #the code_NTEE(X) function has a list to check the missing variables
look = df.ACTIVITY.apply(code_NTEE_V1)
set(trouble)
# Out:
# {0,
#  451,
#  556,
#  578,
#  605,
#  607,
#  610,
#  630,
#  632,
#  650,
#  651,
#  659,
#  681,
#  700,
#  705,
#  713,
#  720,
#  740,
#  750,
#  760,
#  787,
#  801,
#  850,
#  860,
#  899,
#  904,
#  909,
#  923,
#  925,
#  926,
#  927,
#  928,
#  930,
#  931,
#  933,
#  967,
#  990,
#  993,
#  994,
#  995,
#  998,
#  999}

# %% [markdown]
# At this point, I updated my `code_NTEE` function. Open Data for Nonprofit Research recommended [Urban Center for Charitable Statistics](https://nccs.urban.org/publication/irs-activity-codes) site to further identify unfamiliar codes.
#
# I updated lists and created a new list for undefined codes. Also, there were a few ambigious codings that I have decided to drop altogeter. These includes definitions such as "Indians (tribes, cultures, etc.)" , "Government instrumentality or agency", and "947(a)(2) trust". Further man hours are required to shift through the material to categorize them with even more accuracy.

# %% [markdown]
# ### Scrub 2
# Using the updated `code_NTEE_V2` function below, I will move forward with the data cleaning process.

# %%
def code_NTEE_V2(y):
    
    x = adj_len(y)
    
    list_a =list(range(60,120))
    list_b =list(range(30,60)) + [540, 914]
    list_c =list(range(350,380)) + [529]
    list_d =[913]
    list_e =list(range(150,180)) + [531] + list(range(541,544))
    list_f = []
    list_g = []
    list_h = []
    list_i =list(range(460,466)) + [406, 526, 527, 528]
    list_j =list(range(120,150)) + list(range(200,230)) + [920]
    list_k =list(range(230,250)) + [916]
    list_l =list(range(380,400)) + [401]
    list_m =[902]
    list_n =list(range(280,320))
    list_o =list(range(320,350))
    list_p =list(range(563,576)) + [917, 918]
    list_q =list(range(510,514)) + [518, 519, 520, 522, 910, 911, 912]
    list_r =list(range(430,450)) + list(range(480,510)) + [261, 405, 481, 482, 534, 535, 924]
    list_s =list(range(408,430)) + [404, 524, 533, 903, 919, 921]
    list_t =list(range(600,604)) + list(range(560,563))
    list_u =list(range(180,200)) 
    list_v = []
    list_w =list(range(250,253)) + list(range(536,540)) + list(range(905,909)) + [262, 263, 400, 402, 403, 407, 514, 515, 516, 521, 523, 525, 530 , 532, 559, 915]
    list_x =list(range(1,30)) + [517]
    list_y =list(range(264,280)) + [253, 254, 259, 260, 900, 901, 922]
    list_z = []
    
    too_vague = [904, 909, 923] + list(range(925,999))
    not_defined = [256, 257, 466,469, 470, 556, 557, 999] + list(range(450,460)) + list(range(484, 509)) + list(range(576, 600)) + list(range(603,900)) + too_vague

    if x == 0:
        return None
    if x in list_a:
        return 'A'
    if x in list_b:
        return 'B'
    if x in list_c:
        return 'C'
    if x in list_d:
        return 'D'
    if x in list_e:
        return 'E'
    if x in list_f:
        return 'F'
    if x in list_g:
        return 'G'
    if x in list_h:
        return 'H'
    if x in list_i:
        return 'I'
    if x in list_j:
        return 'J'
    if x in list_k:
        return 'K'
    if x in list_l:
        return 'L' 
    if x in list_m:
        return 'M'
    if x in list_n:
        return 'N'
    if x in list_o:
        return 'O'
    if x in list_p:
        return 'P'
    if x in list_q:
        return 'Q'
    if x in list_r:
        return 'R'
    if x in list_s:
        return 'S'
    if x in list_t:
        return 'T'
    if x in list_u:
        return 'U'
    if x in list_v:
        return 'V'
    if x in list_w:
        return 'W'
    if x in list_x:
        return 'X'
    if x in list_y:
        return 'Y'
    if x in list_z:
        return 'Z'
    if x in not_defined:
        return None
    else:
        trouble.append(x)

# %%
trouble = [] #the code_NTEE(X) function has a list to check the missing variables
look = df.ACTIVITY.apply(code_NTEE_V2)
trouble
# Out:
# []

# %% [markdown]
# There were no trouble codes anymore. We will merge the changes and tidy up the last few things wrong with the data.
# Keep in mind that this step heavily effects the target outcome in the joint dataset. This is can be a point of improvements in any further analysis of this data.

# %%
df.NTEE_CD.isna().sum()
# Out:
# 372402

# %%
df.NTEE_CD.fillna(df.ACTIVITY.apply(code_NTEE_V2), inplace=True)

# %%
print(df.NTEE_CD.isna().sum())
df[df.NTEE_CD.isna()].head()
# Out:
# 11515
#           EIN                 STREET       CITY STATE         ZIP  GROUP  \
# 150  10192722            109 MAIN ST    HOULTON    ME  04730-2123      0
# 235  10211564             PO BOX 888   LEWISTON    ME  04243-0888      0
# 411  10241354           10 BRIDGE ST    RUMFORD    ME  04276-2007      0
# 547  10279581  123 MEDICAL CENTER DR  BRUNSWICK    ME  04011-2652      0
# 637  10315181             PO BOX 192   PHILLIPS    ME  04966-0192      0
#
#      SUBSECTION  AFFILIATION  CLASSIFICATION  DEDUCTIBILITY  ...  STATUS  \
# 150           6            3            3000              2  ...       1
# 235           3            3            1000              1  ...       1
# 411           6            3            3000              2  ...       1
# 547           3            3            1000              1  ...       1
# 637           3            3            1000              1  ...       1
#
#      FILING_REQ_CD  PF_FILING_REQ_CD  ACCT_PD  ASSET_AMT  INCOME_AMT  \
# 150              1                 0       12    27756.0    167351.0
# 235              1                 0       12  2638982.0   1287903.0
# 411              1                 0        6    23675.0     60997.0
# 547              1                 0        6   164903.0    104651.0
# 637              2                 0       12        0.0         0.0
#
#      REVENUE_AMT  NTEE_CD  RULEYEAR                               NAME_FULL
# 150      83314.0     None      1946            HOULTON CHAMBER OF COMMERCE
# 235    1270323.0     None      1961  UNITED WAY OF ANDROSCOGGIN COUNTY INC
# 411      42828.0     None      1944       RIVER VALLEY CHAMBER OF COMMERCE
# 547     104651.0     None      1973  MIDCOAST HOSPITAL-BRUNSWICK AUXILIARY
# 637          0.0     None      1972      SANDY RIVER AMBULANCE ASSOCIATION
#
# [5 rows x 23 columns]

# %% [markdown]
# Finally dropping the remaining ~11K rows that don't have a clear NTEE code.

# %%
df = df.dropna(subset=['NTEE_CD'])
df.shape
# Out:
# (1157394, 23)

# %%
df.isna().sum()
# Out:
# EIN                   0
# STREET                1
# CITY                  0
# STATE               894
# ZIP                   0
# GROUP                 0
# SUBSECTION            0
# AFFILIATION           0
# CLASSIFICATION        0
# DEDUCTIBILITY         0
# FOUNDATION            0
# ACTIVITY              0
# ORGANIZATION          0
# STATUS                0
# FILING_REQ_CD         0
# PF_FILING_REQ_CD      0
# ACCT_PD               0
# ASSET_AMT             0
# INCOME_AMT            0
# REVENUE_AMT           0
# NTEE_CD               0
# RULEYEAR              0
# NAME_FULL             0
# dtype: int64

# %% [markdown]
# Now to drop the very small subset of missing values.

# %%
df.dropna(subset=['STATE', 'STREET'], inplace=True) #dropping the missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1156499 entries, 12 to 1691185
# Data columns (total 23 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   EIN               1156499 non-null  int64
#  1   STREET            1156499 non-null  object
#  2   CITY              1156499 non-null  object
#  3   STATE             1156499 non-null  object
#  4   ZIP               1156499 non-null  object
#  5   GROUP             1156499 non-null  int64
#  6   SUBSECTION        1156499 non-null  int64
#  7   AFFILIATION       1156499 non-null  int64
#  8   CLASSIFICATION    1156499 non-null  int64
#  9   DEDUCTIBILITY     1156499 non-null  int64
#  10  FOUNDATION        1156499 non-null  int64
#  11  ACTIVITY          1156499 non-null  int64
#  12  ORGANIZATION      1156499 non-null  int64
#  13  STATUS            1156499 non-null  int64
#  14  FILING_REQ_CD     1156499 non-null  int64
#  15  PF_FILING_REQ_CD  1156499 non-null  int64
#  16  ACCT_PD           1156499 non-null  int64
#  17  ASSET_AMT         1156499 non-null  float64
#  18  INCOME_AMT        1156499 non-null  float64
#  19  REVENUE_AMT       1156499 non-null  float64
#  20  NTEE_CD           1156499 non-null  object
#  21  RULEYEAR          1156499 non-null  int64
#  22  NAME_FULL         1156499 non-null  object
# dtypes: float64(3), int64(14), object(6)
# memory usage: 211.8+ MB

# %% [markdown]
# Now that I have my target variable set, albeit currently in two different formats, it is time to start removing the some excess columns and divide the data.
#
# Removing the other columns that I won't be using to model my data with.

# %%
df = df.drop(['NAME_FULL', 'STREET', 'ZIP', 'CITY','ACTIVITY', 'EIN', 'ACCT_PD'], axis=1)

# %% [markdown]
# Now taking a look at `NTEE_CD` column and getting the proper format.

# %%
df.NTEE_CD.head()
# Out:
# 12    A80
# 13    S19
# 14    N64
# 15      J
# 16      B
# Name: NTEE_CD, dtype: object

# %% [markdown]
# Lets take this opportunity to split off a subsection of this data set that was given by the IRS in preparation for running in a model.

# %%
df_post = df[df.NTEE_CD.apply(lambda x: len(str(x)) > 2)]
df_post.shape
# Out:
# (795612, 16)

# %% [markdown]
# Lets remove the more specific coding form the `NTEE` column, just leaving the one of the 26 categories.

# %%
df.NTEE_CD = df.NTEE_CD.apply(lambda x: x[0:1])
df_post.NTEE_CD = df.NTEE_CD.apply(lambda x: x[0:1])

df.NTEE_CD.head(), df_post.NTEE_CD.head()
# Out:
# C:\Users\Jonct\anaconda3\lib\site-packages\pandas\core\generic.py:5165: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# (12    A
#  13    S
#  14    N
#  15    J
#  16    B
#  Name: NTEE_CD, dtype: object,
#  12    A
#  13    S
#  14    N
#  30    A
#  38    Y
#  Name: NTEE_CD, dtype: object)

# %% [markdown]
# ### Breaking into subsets

# %%
df.NTEE_CD.value_counts(normalize=True)
# Out:
# B    1.972142e-01
# N    8.880596e-02
# P    8.717863e-02
# A    8.598883e-02
# W    6.278345e-02
# X    5.447735e-02
# S    4.774928e-02
# J    4.689239e-02
# O    4.173199e-02
# E    3.924344e-02
# Y    3.749593e-02
# T    3.744491e-02
# L    2.417036e-02
# Q    2.404066e-02
# D    2.282060e-02
# C    2.014355e-02
# M    1.368873e-02
# K    1.244878e-02
# F    1.176828e-02
# I    9.862525e-03
# R    9.572857e-03
# G    9.338529e-03
# Z    6.274108e-03
# H    3.946393e-03
# U    3.782104e-03
# V    1.122353e-03
# 0    1.037614e-05
# c    2.594036e-06
# 8    8.646787e-07
# Name: NTEE_CD, dtype: float64

# %% [markdown]
# There seems to be some extraneous information in our target variables. Also we have some class balancing issues to keep in mind when we are running our models. Lets excise the odd labels then move forward.

# %%
removal = ['c', '0', '8'] #Setting what we don't want

mask = df[df.NTEE_CD.isin(removal)] #Finding the rows that contain those values and masking a mask
df_full = df.drop(mask.index) #Dropping based on index

mask_post = df_post[df_post.NTEE_CD.isin(removal)] #Finding the rows that contain those values and masking a mask
df_post = df_post.drop(mask.index)


df_full.shape, df_post.shape
# Out:
# ((1156483, 16), (795596, 16))

# %% [markdown]
# ___

# %% [markdown]
# A good data cleaning tip, when ever making new `DataFrames` reset the index. There is going to be a lot of merging later of respected dataframes so this ensures starting off with a simple index.

# %%
df_full.reset_index(drop=True, inplace=True)
df_post.reset_index(drop=True, inplace=True)

# %% [markdown]
# ___

# %%
df_post.NTEE_CD.value_counts()
# Out:
# B    122782
# P     96913
# A     80769
# N     71509
# X     53548
# S     50520
# O     37988
# E     33259
# T     32599
# D     26164
# L     22248
# C     19483
# Q     19441
# W     18994
# M     15669
# F     13608
# Y     13209
# J     11440
# K     11174
# I     10889
# G     10797
# Z      7251
# R      5674
# H      4564
# U      3806
# V      1298
# Name: NTEE_CD, dtype: int64

# %%
df_full.NTEE_CD.value_counts()
# Out:
# B    228078
# N    102704
# P    100822
# A     99446
# W     72609
# X     63003
# S     55222
# J     54231
# O     48263
# E     45385
# Y     43364
# T     43305
# L     27953
# Q     27803
# D     26392
# C     23296
# M     15831
# K     14397
# F     13610
# I     11406
# R     11071
# G     10800
# Z      7256
# H      4564
# U      4374
# V      1298
# Name: NTEE_CD, dtype: int64

# %% [markdown]
# Now that we have both the full and post datasets, we have one more to make.
#
# I am going to group by the `target` variable and then take subsamples of 10,000 of each group. There are four `target` variables that won't be able to be completely full, given n=10000, without using replacement when taking the samples. If replacement were to be used, there would be a greater chance that our models would over fit on those specific `target`s.
#
# I will manually remove labels with less than 10K instances and then append them back at the end. Using the [`pd.sample()`](http://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html), I randomly take the necessary samples from the population then create my slimmed down dataset.

# %%
to_append = df_full[df_full.NTEE_CD.isin(['Z','H','U','V'])]

df_downsize = df_full[~df_full.NTEE_CD.isin(['Z','H','U','V'])] #The tilda is a negation, everything BUT those listed


df_downsize.shape
# Out:
# (1138991, 16)

# %%
df_downsize = df_downsize.groupby('NTEE_CD', as_index=False).apply(lambda x: x.sample(10000, random_state=26))

df_downsize = df_downsize.append(to_append)

df_downsize.head()
# Out:
#              STATE  GROUP  SUBSECTION  AFFILIATION  CLASSIFICATION  \
# (0, 1154416)    HI      0           3            3            1000
# (0, 650062)     TX      0           3            3            2000
# (0, 758056)     CA      0           3            3            2000
# (0, 24643)      NY      0           3            3            1200
# (0, 381128)     MI   9516           3            9            1000
#
#               DEDUCTIBILITY  FOUNDATION  ORGANIZATION  STATUS  FILING_REQ_CD  \
# (0, 1154416)              1          15             1       1              1
# (0, 650062)               1          16             1       1              2
# (0, 758056)               1          15             1       1              1
# (0, 24643)                1          15             5       1              2
# (0, 381128)               1          16             1       1              2
#
#               PF_FILING_REQ_CD  ASSET_AMT  INCOME_AMT  REVENUE_AMT NTEE_CD  \
# (0, 1154416)                 0  4364983.0    854128.0     827297.0       A
# (0, 650062)                  0        0.0         0.0          0.0       A
# (0, 758056)                  0  1215885.0    198033.0     192034.0       A
# (0, 24643)                   0        0.0         0.0          0.0       A
# (0, 381128)                  0        0.0         0.0          0.0       A
#
#               RULEYEAR
# (0, 1154416)      1996
# (0, 650062)       1991
# (0, 758056)       2003
# (0, 24643)        2004
# (0, 381128)       1995

# %% [markdown]
# ___

# %% [markdown]
# Clean. Clean. Clean.

# %%
df_downsize.reset_index(drop=True, inplace=True)

# %% [markdown]
# ___

# %%
df_full.head()
# Out:
#   STATE  GROUP  SUBSECTION  AFFILIATION  CLASSIFICATION  DEDUCTIBILITY  \
# 0    ME      0           3            3            1000              1
# 1    MA      0           3            3            1000              1
# 2    NJ      0           3            3            1000              1
# 3    ME      0           3            3            2000              1
# 4    ME    287           7            9            1000              2
#
#    FOUNDATION  ORGANIZATION  STATUS  FILING_REQ_CD  PF_FILING_REQ_CD  \
# 0          15             1       1              2                 0
# 1          16             1       1              2                 0
# 2          16             1       1              1                 0
# 3          15             1       1              1                 0
# 4           0             5       1              2                 0
#
#    ASSET_AMT  INCOME_AMT  REVENUE_AMT NTEE_CD  RULEYEAR
# 0        0.0         0.0          0.0       A      2000
# 1        0.0         0.0          0.0       S      2015
# 2    62462.0    140685.0     140685.0       N      2012
# 3   233819.0    180773.0     127013.0       J      1993
# 4        0.0         0.0          0.0       B      1941

# %%
df_downsize.shape
# Out:
# (237492, 16)

# %%
df_downsize.NTEE_CD.value_counts(normalize=True)
# Out:
# J    0.042107
# B    0.042107
# G    0.042107
# W    0.042107
# T    0.042107
# Q    0.042107
# C    0.042107
# F    0.042107
# L    0.042107
# N    0.042107
# A    0.042107
# Y    0.042107
# M    0.042107
# D    0.042107
# K    0.042107
# X    0.042107
# S    0.042107
# O    0.042107
# I    0.042107
# R    0.042107
# P    0.042107
# E    0.042107
# Z    0.030553
# H    0.019217
# U    0.018417
# V    0.005465
# Name: NTEE_CD, dtype: float64

# %% [markdown]
# Good, these all look like my expected outcomes.

# %% [markdown]
# Now lets take a quick look at our target distribution.

# %%
target_count_post = pd.value_counts(df_post['NTEE_CD'].values)
target_count_post.plot.barh(figsize=(12,8))
plt.title('Count of Major Group Categories for Post Dataset');

# %%
target_count_full = pd.value_counts(df_full['NTEE_CD'].values)
target_count_full.plot.barh(figsize=(12,8))
plt.title('Count of Major Group Categories for Full Dataset');

# %% [markdown]
# ## Explore
# Lets check the class balance for the rest of the columns

# %%
fig = plt.figure(figsize=(24,12))
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)

states_1 =  sorted(list(df_downsize.STATE.unique()), reverse=True)
states_2 =  sorted(list(df_full.STATE.unique()), reverse=True)
states_3 =  sorted(list(df_post.STATE.unique()), reverse=True)

ax1.barh(states_1, df_downsize.groupby('STATE')['NTEE_CD'].count(), color='r' )
ax1.set_title('Non-profits per region for Downsized Dataset')

ax2.barh(states_2, df_full.groupby('STATE')['NTEE_CD'].count(), color='w', edgecolor='black' )
ax2.set_title('Non-profits per region for Full Dataset')

ax3.barh(states_3, df_post.groupby('STATE')['NTEE_CD'].count(), color='b')
ax3.set_title('Non-profits per region for Post-95 Dataset')
plt.show()

# %% [markdown]
# State/Region | USPS Abbreviated Code
# --------------------|--------------|
# U.S. Armed Forces – Americas  | AA
#  U.S. Armed Forces – Europe  | AE
#  U.S. Armed Forces – Pacific  | AP
#  American Samoa                         | AS
#  Micronesia                   | FM
#  Marshall Islands                    | MH
#  Palau                    | PW
#  U.S. Virgin Islands | VI
#
#  Keeping in mind all three charts exist on a different scale, they all look to have the same distribution.

# %%
df.columns
# Out:
# Index(['STATE', 'GROUP', 'SUBSECTION', 'AFFILIATION', 'CLASSIFICATION',
#        'DEDUCTIBILITY', 'FOUNDATION', 'ORGANIZATION', 'STATUS',
#        'FILING_REQ_CD', 'PF_FILING_REQ_CD', 'ASSET_AMT', 'INCOME_AMT',
#        'REVENUE_AMT', 'NTEE_CD', 'RULEYEAR'],
#       dtype='object')

# %%
top_values = []
for col in df.columns:
    top_values.append(df[col].value_counts(normalize=True)[:5])
top_values
# Out:
# [CA    0.103421
#  TX    0.068871
#  NY    0.060910
#  FL    0.048956
#  PA    0.042625
#  Name: STATE, dtype: float64,
#  0       0.775831
#  820     0.007404
#  188     0.006774
#  925     0.006450
#  1072    0.005382
#  Name: GROUP, dtype: float64,
#  3    0.731922
#  4    0.058842
#  6    0.049164
#  5    0.035976
#  7    0.035699
#  Name: SUBSECTION, dtype: float64,
#  3    0.772426
#  9    0.221409
#  6    0.002687
#  1    0.002476
#  2    0.000802
#  Name: AFFILIATION, dtype: float64,
#  1000    0.553376
#  2000    0.179143
#  1200    0.105087
#  3000    0.066521
#  7000    0.027562
#  Name: CLASSIFICATION, dtype: float64,
#  1    0.796841
#  2    0.197174
#  0    0.005880
#  4    0.000105
#  Name: DEDUCTIBILITY, dtype: float64,
#  15    0.431279
#  0     0.267942
#  16    0.247533
#  11    0.016504
#  17    0.014625
#  Name: FOUNDATION, dtype: float64,
#  1    0.754107
#  5    0.230146
#  2    0.012890
#  0    0.001865
#  3    0.000931
#  Name: ORGANIZATION, dtype: float64,
#  1     0.999615
#  2     0.000296
#  25    0.000059
#  12    0.000030
#  Name: STATUS, dtype: float64,
#  2     0.635579
#  1     0.350961
#  6     0.010149
#  0     0.002041
#  13    0.000552
#  Name: FILING_REQ_CD, dtype: float64,
#  0    0.999258
#  1    0.000725
#  3    0.000017
#  Name: PF_FILING_REQ_CD, dtype: float64,
#  0.0        0.554308
#  1.0        0.009307
#  100.0      0.000181
#  1000.0     0.000133
#  500.0      0.000128
#  200.0      0.000085
#  5000.0     0.000074
#  2000.0     0.000073
#  1500.0     0.000058
#  300.0      0.000058
#  50.0       0.000057
#  10.0       0.000048
#  150.0      0.000048
#  3000.0     0.000045
#  25.0       0.000044
#  10000.0    0.000044
#  2500.0     0.000042
#  5.0        0.000042
#  Name: ASSET_AMT, dtype: float64,
#  0.0        0.562415
#  1000.0     0.000254
#  5000.0     0.000191
#  500.0      0.000190
#  100.0      0.000188
#  1.0        0.000173
#  10000.0    0.000157
#  2000.0     0.000144
#  200.0      0.000112
#  3000.0     0.000110
#  1500.0     0.000106
#  2500.0     0.000096
#  2.0        0.000090
#  6000.0     0.000088
#  5.0        0.000084
#  Name: INCOME_AMT, dtype: float64,
#  0.0        0.563671
#  1000.0     0.000249
#  500.0      0.000187
#  5000.0     0.000183
#  100.0      0.000182
#  1.0        0.000169
#  10000.0    0.000155
#  2000.0     0.000138
#  3000.0     0.000112
#  200.0      0.000111
#  1500.0     0.000105
#  2500.0     0.000096
#  2.0        0.000090
#  6000.0     0.000088
#  5.0        0.000083
#  Name: REVENUE_AMT, dtype: float64,
#  B    0.197214
#  N    0.088806
#  P    0.087179
#  A    0.085989
#  W    0.062783
#  Name: NTEE_CD, dtype: float64,
#  2014    0.074811
#  2015    0.052715
#  2016    0.051775
#  2017    0.045742
#  2013    0.031564
#  Name: RULEYEAR, dtype: float64]

# %% [markdown]
# We can see here that most of our classes aren't balanced throughout the data. While not ideal, we can still use different methods to get around the imbalanced data set. I will still plan on running a base line model. We need to preform scaling for the continuous columns that are left and then create dummy variable for the categorical columns.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

cont_scaled_full = scaler.fit_transform(df_full[['INCOME_AMT', 'REVENUE_AMT', 'ASSET_AMT']])
cont_scaled_post = scaler.fit_transform(df_post[['INCOME_AMT', 'REVENUE_AMT', 'ASSET_AMT']])
cont_scaled_downsize = scaler.fit_transform(df_downsize[['INCOME_AMT', 'REVENUE_AMT', 'ASSET_AMT']])

# %%
df_scaled_full = pd.DataFrame(cont_scaled_full, columns=['INCOME_AMT_scaled', 'REVENUE_AMT_scaled', 'ASSET_AMT_scaled'])
df_scaled_post = pd.DataFrame(cont_scaled_post, columns=['INCOME_AMT_scaled', 'REVENUE_AMT_scaled', 'ASSET_AMT_scaled'])
df_scaled_downsize = pd.DataFrame(cont_scaled_downsize, columns=['INCOME_AMT_scaled', 'REVENUE_AMT_scaled', 'ASSET_AMT_scaled'])

# %%
target_full = pd.DataFrame(df_full.NTEE_CD)
col_full = df_full.drop(['NTEE_CD'], axis=1)

# %%
target_post = pd.DataFrame(df_post.NTEE_CD)
col_post = df_post.drop(['NTEE_CD'], axis=1)

# %%
target_down = pd.DataFrame(df_downsize.NTEE_CD)
col_down = df_downsize.drop(['NTEE_CD'], axis=1)

# %%
data_full = pd.get_dummies(col_full, columns=['STATE', 'GROUP', 'SUBSECTION', 'AFFILIATION', 
                                       'CLASSIFICATION', 'DEDUCTIBILITY', 'FOUNDATION', 
                                       'ORGANIZATION', 'STATUS', 'FILING_REQ_CD', 
                                       'PF_FILING_REQ_CD'])

# %%
data_post = pd.get_dummies(col_post, columns=['STATE', 'GROUP', 'SUBSECTION', 'AFFILIATION', 
                                       'CLASSIFICATION', 'DEDUCTIBILITY', 'FOUNDATION', 
                                       'ORGANIZATION', 'STATUS', 'FILING_REQ_CD', 
                                       'PF_FILING_REQ_CD'])

# %%
data_down = pd.get_dummies(col_down, columns=['STATE', 'GROUP', 'SUBSECTION', 'AFFILIATION', 
                                       'CLASSIFICATION', 'DEDUCTIBILITY', 'FOUNDATION', 
                                       'ORGANIZATION', 'STATUS', 'FILING_REQ_CD', 
                                       'PF_FILING_REQ_CD'])

# %%
data_full.INCOME_AMT = df_scaled_full.INCOME_AMT_scaled
data_full.ASSET_AMT = df_scaled_full.ASSET_AMT_scaled
data_full.REVENUE_AMT = df_scaled_full.REVENUE_AMT_scaled

data_post.INCOME_AMT = df_scaled_post.INCOME_AMT_scaled
data_post.ASSET_AMT = df_scaled_post.ASSET_AMT_scaled
data_post.REVENUE_AMT = df_scaled_post.REVENUE_AMT_scaled

data_down.INCOME_AMT = df_scaled_downsize.INCOME_AMT_scaled
data_down.ASSET_AMT = df_scaled_downsize.ASSET_AMT_scaled
data_down.REVENUE_AMT = df_scaled_downsize.REVENUE_AMT_scaled

# %%
data_full.drop(labels=['INCOME_AMT', 'REVENUE_AMT', 'ASSET_AMT'], axis=1, inplace=True)
data_post.drop(labels=['INCOME_AMT', 'REVENUE_AMT', 'ASSET_AMT'], axis=1, inplace=True)
data_down.drop(labels=['INCOME_AMT', 'REVENUE_AMT', 'ASSET_AMT'], axis=1, inplace=True)

# %%
from sklearn.model_selection import train_test_split
X_train_full, X_test_full, y_train_full, y_test_full = train_test_split(data_full, target_full, test_size = .2)

# %%
X_train_post, X_test_post, y_train_post, y_test_post = train_test_split(data_post, target_post, test_size = .2)

# %%
X_train_down, X_test_down, y_train_down, y_test_down = train_test_split(data_down, target_down, test_size = .2)

# %%
X_train_post.to_pickle('./data/X_train_post')
X_test_post.to_pickle('./data/X_test_post')
y_train_post.to_pickle('./data/y_train_post')
y_test_post.to_pickle('./data/y_test_post')

# %%
X_train_down.to_pickle('./data/X_train_down')
X_test_down.to_pickle('./data/X_test_down')
y_train_down.to_pickle('./data/y_train_down')
y_test_down.to_pickle('./data/y_test_down')

# %%
X_train_full.to_pickle('./data/X_train_full')
X_test_full.to_pickle('./data/X_test_full')
y_train_full.to_pickle('./data/y_train_full')
y_test_full.to_pickle('./data/y_test_full')

# %% [markdown]
# ## Data Sets
# ___

# %% [markdown]
# ### Full

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

X_train_full = pd.read_pickle('./data/X_train_full')
y_train_full = pd.read_pickle('./data/y_train_full')
X_test_full = pd.read_pickle('./data/X_test_full')
y_test_full = pd.read_pickle('./data/y_test_full')

# %% [markdown]
# ___

# %% [markdown]
# ### Post - 1995

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

X_train_post = pd.read_pickle('./data/X_train_post')
y_train_post = pd.read_pickle('./data/y_train_post')
X_test_post = pd.read_pickle('./data/X_test_post')
y_test_post = pd.read_pickle('./data/y_test_post')

# %% [markdown]
# ___

# %% [markdown]
# ### Downsized

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

X_train_down = pd.read_pickle('./data/X_train_down')
y_train_down = pd.read_pickle('./data/y_train_down')
X_test_down = pd.read_pickle('./data/X_test_down')
y_test_down = pd.read_pickle('./data/y_test_down')

# %% [markdown]
# ___

# %% [markdown]
# # MODELS
#
# Starting off with a simple model to give us a baseline. Our target consists of 26 classes. If any of these Nonprofits were categorized truly at random, the chance of getting any one entry correct would be roughly 4%. The overall goal is to obtain the highest accuracy as we can.

# %%
results = {'DecisionTree': {'Full' : {},
                            'Post' : {},
                            'Down' : {}},
          'RandomForest' : {'Full' : {},
                            'Post' : {},
                            'Down' : {}},
          'XGB'          : {'Full' : {},
                            'Post' : {},
                            'Down' : {}}} #Dictionary to keep track of results of all the models

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_curve, auc
from sklearn import tree 
from sklearn.preprocessing import LabelEncoder
from yellowbrick.classifier import ConfusionMatrix
from sklearn.metrics import classification_report
import time
# Out:
# C:\Users\Jonct\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from sklearn.tree import DecisionTreeClassifier

clf_DT = DecisionTreeClassifier(max_features='auto', max_depth=10, min_samples_split=1000)

# %% [markdown]
# ### Decision Tree Full

# %%
start_time = time.time()

clf_DT.fit(X_train_full, y_train_full)

fit_time = (time.time() - start_time)
print(f'-------{fit_time}s seconds------')
results['DecisionTree']['Full']['FitTime'] = fit_time
# Out:
# -------218.92935371398926s seconds------

# %%
y_hat_full = clf_DT.predict(X_test_full)

# %%
acc = accuracy_score(y_test_full,y_hat_full) * 100
print("Accuracy is :{0}".format(acc))
results['DecisionTree']['Full']['Accuracy'] = acc
# Out:
# Accuracy is :21.89090217339611

# %%
fig, ax = plt.subplots(figsize=(18,12)) #Making the final out put a bit more readable than the standard
cm = ConfusionMatrix(clf_DT, ax=ax) #This instance takes in an axes to add to a exisiting figure.

cm.score(X_test_full, y_test_full)

# How did we do?
cm.poof()
# Out:
# C:\Users\Jonct\anaconda3\lib\site-packages\sklearn\base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# C:\Users\Jonct\anaconda3\lib\site-packages\yellowbrick\classifier\base.py:232: YellowbrickWarning: could not determine class_counts_ from previously fitted classifier
#   YellowbrickWarning,
# <AxesSubplot:title={'center':'DecisionTreeClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %% [markdown]
# Now lets check out the weights on the descions made by the tree.

# %%
clf_DT.feature_importances_
# Out:
# array([0.0001461, 0.       , 0.       , ..., 0.       , 0.       ,
#        0.       ])

# %% [markdown]
# ### Decision Tree Post

# %%
start_time = time.time()

clf_DT.fit(X_train_post, y_train_post)

fit_time = (time.time() - start_time)
print(f'-------{fit_time}s seconds------')
results['DecisionTree']['Post']['FitTime'] = fit_time
# Out:
# -------58.23425626754761s seconds------

# %%
y_hat_post = clf_DT.predict(X_test_post)

# %%
acc = accuracy_score(y_test_post,y_hat_post) * 100
print("Accuracy is :{0}".format(acc))
results['DecisionTree']['Post']['Accuracy'] = acc
# Out:
# Accuracy is :20.934514831573654

# %%
fig, ax = plt.subplots(figsize=(18,12)) #Making the final out put a bit more readable than the standard
cm = ConfusionMatrix(clf_DT, ax=ax) #This instance takes in an axes to add to a exisiting figure.

cm.score(X_test_post, y_test_post)

# How did we do?
cm.poof()
# Out:
# C:\Users\Jonct\anaconda3\lib\site-packages\sklearn\base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# C:\Users\Jonct\anaconda3\lib\site-packages\yellowbrick\classifier\base.py:232: YellowbrickWarning: could not determine class_counts_ from previously fitted classifier
#   YellowbrickWarning,
# <AxesSubplot:title={'center':'DecisionTreeClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %% [markdown]
# ### Decision Tree Downsized

# %%
start_time = time.time()

clf_DT.fit(X_train_down, y_train_down)
fit_time = (time.time() - start_time)
print(f'-------{fit_time}s seconds------')
results['DecisionTree']['Down']['FitTime'] = fit_time
# Out:
# -------5.247431755065918s seconds------

# %%
y_hat_down = clf_DT.predict(X_test_down)

# %%
acc = accuracy_score(y_test_down,y_hat_down) * 100
print("Accuracy is :{0}".format(acc))
results['DecisionTree']['Down']['Accuracy'] = acc
# Out:
# Accuracy is :12.452893745131476

# %%
from yellowbrick.classifier import ConfusionMatrix
fig, ax = plt.subplots(figsize=(18,12)) #Making the final out put a bit more readable than the standard
cm = ConfusionMatrix(clf_DT, ax=ax) #This instance takes in an axes to add to a exisiting figure.

cm.score(X_test_down, y_test_down)

# How did we do?
cm.poof()
# Out:
# C:\Users\Jonct\anaconda3\lib\site-packages\sklearn\base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# C:\Users\Jonct\anaconda3\lib\site-packages\yellowbrick\classifier\base.py:232: YellowbrickWarning: could not determine class_counts_ from previously fitted classifier
#   YellowbrickWarning,
# <AxesSubplot:title={'center':'DecisionTreeClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %% [markdown]
# With both sets of data, there are similar classes that were heavily chosen over others [B, N, S, Y]. Both sets also placed a lot of information into category B, which is to be expected since it is out largest class at almost 20% of the data.
#
# Now lets run some models that can account for imbalanced classes.

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators=100, max_depth= 10, max_features='auto',min_samples_split=1000)

# %% [markdown]
# ### Random Forest Full

# %%
start_time = time.time()

forest.fit(X_train_full, y_train_full)

fit_time = (time.time() - start_time)
print(f'-------{fit_time}s seconds------')
results['RandomForest']['Full']['FitTime'] = fit_time
# Out:
# C:\Users\Jonct\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# -------609.259092092514s seconds------

# %%
acc = forest.score(X_train_full, y_train_full) * 100
print("Accuracy is :{0}".format(acc))
results['RandomForest']['Full']['Accuracy'] = acc
# Out:
# Accuracy is :31.354884315153924

# %%
fig, ax = plt.subplots(figsize=(18,12)) #Making the final out put a bit more readable than the standard
cm = ConfusionMatrix(forest, ax=ax) #This instance takes in an axes to add to a exisiting figure.

cm.score(X_test_full, y_test_full)

# How did we do?
cm.poof()
# Out:
# C:\Users\Jonct\anaconda3\lib\site-packages\sklearn\base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# C:\Users\Jonct\anaconda3\lib\site-packages\yellowbrick\classifier\base.py:232: YellowbrickWarning: could not determine class_counts_ from previously fitted classifier
#   YellowbrickWarning,
# <AxesSubplot:title={'center':'RandomForestClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %% [markdown]
# ### Random Forest Post

# %%
start_time = time.time()

forest.fit(X_train_post, y_train_post)

fit_time = (time.time() - start_time)
print(f'-------{fit_time}s seconds------')
results['RandomForest']['Post']['FitTime'] = fit_time
# Out:
# C:\Users\Jonct\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# -------271.7068748474121s seconds------

# %%
acc = forest.score(X_train_post, y_train_post) * 100
print("Accuracy is :{0}".format(acc))
results['RandomForest']['Post']['Accuracy'] = acc
# Out:
# Accuracy is :32.18314594737272

# %%
fig, ax = plt.subplots(figsize=(18,12)) #Making the final out put a bit more readable than the standard
cm = ConfusionMatrix(forest, ax=ax) #This instance takes in an axes to add to a exisiting figure.

cm.score(X_test_post, y_test_post)

# How did we do?
cm.poof()
# Out:
# C:\Users\Jonct\anaconda3\lib\site-packages\sklearn\base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# C:\Users\Jonct\anaconda3\lib\site-packages\yellowbrick\classifier\base.py:232: YellowbrickWarning: could not determine class_counts_ from previously fitted classifier
#   YellowbrickWarning,
# <AxesSubplot:title={'center':'RandomForestClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %% [markdown]
# ### Random Forest Downsized

# %%
start_time = time.time()

forest.fit(X_train_down, y_train_down)

fit_time = (time.time() - start_time)
print(f'-------{fit_time}s seconds------')
results['RandomForest']['Down']['FitTime'] = fit_time
# Out:
# C:\Users\Jonct\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# -------48.1766095161438s seconds------

# %%
acc = forest.score(X_train_down, y_train_down) * 100
print("Accuracy is :{0}".format(acc))
results['RandomForest']['Down']['Accuracy'] = acc
# Out:
# Accuracy is :28.80948245461675

# %%
fig, ax = plt.subplots(figsize=(18,12)) #Making the final out put a bit more readable than the standard
cm = ConfusionMatrix(forest, ax=ax) #This instance takes in an axes to add to a exisiting figure.

cm.score(X_test_down, y_test_down)

# How did we do?
cm.poof()
# Out:
# C:\Users\Jonct\anaconda3\lib\site-packages\sklearn\base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# C:\Users\Jonct\anaconda3\lib\site-packages\yellowbrick\classifier\base.py:232: YellowbrickWarning: could not determine class_counts_ from previously fitted classifier
#   YellowbrickWarning,
# <AxesSubplot:title={'center':'RandomForestClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %% [markdown]
# As a baseline, the accuracy of my model increased by 7%. Lets run XGBoost and see if it does any better. I will then perform GridSearchCV on the model with the highest baseline accuracy.

# %% [markdown]
# ## XGBoost
#
# At this point, lets try out the powerhouse that is XGBoost. Before changing the data sets in the memory and computationally efficient [DMatrix](https://xgboost.readthedocs.io/en/latest/python/python_api.html#xgboost.DMatrix) data type, I will need to process my target variable once more. The DMatrix prefers integers rather than strings, so a quick LabelEncoder will take care of that.

# %%
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

le = LabelEncoder()

# %% [markdown]
# ### XGB Full

# %%
#le.fit(y_train_full)
#list(le.classes_)
#y_train_le_full = le.transform(y_train_full.NTEE_CD)
#y_test_le_full = le.transform(y_test_full.NTEE_CD)

# %%
#dtrain_full = xgb.DMatrix(X_train_full, label=y_train_le_full)

# %%
#dvalid_full = xgb.DMatrix(X_test_full, label=y_test_le_full)

# %% [markdown]
# My hardware is unable to even convert the full sized data set into the DMatrix data type. Knowing enough about XGBoost, this means that my fitting my model in the sklearn form will fail as well. I will have to move onto my other data sets.

# %% [markdown]
# ### XGB Post

# %%
le.fit(y_train_post)
list(le.classes_)
y_train_le_post = le.transform(y_train_post.NTEE_CD)
y_test_le_post = le.transform(y_test_post.NTEE_CD)
# Out:
# C:\Users\Jonct\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
dvalid_post = xgb.DMatrix(X_test_post, label=y_test_le_post)

# %%
dtrain_post = xgb.DMatrix(X_train_post, label=y_train_le_post)

# %% [markdown]
# Using the same parameters as I used in the previous models, lets get XGBoost started.

# %%
param_post = [('max_depth', 4), ('objective', 'multi:softprob'), ('eval_metric', 'merror'), ('eval_metric', 'mlogloss'), ('num_class', 26)]
 
num_round = 10

watchlist = [(dvalid_post,'eval'), (dtrain_post,'train')]

evals_result = {}
model_post = xgb.train(param_post, dtrain_post, num_round, watchlist, evals_result=evals_result)
# Out:
# [0]	eval-merror:0.66870	eval-mlogloss:2.65447	train-merror:0.66730	train-mlogloss:2.65123
# [1]	eval-merror:0.64947	eval-mlogloss:2.51322	train-merror:0.64918	train-mlogloss:2.51115
# [2]	eval-merror:0.64150	eval-mlogloss:2.42931	train-merror:0.64125	train-mlogloss:2.42678
# [3]	eval-merror:0.63798	eval-mlogloss:2.37161	train-merror:0.63694	train-mlogloss:2.36899
# [4]	eval-merror:0.63626	eval-mlogloss:2.32977	train-merror:0.63538	train-mlogloss:2.32720
# [5]	eval-merror:0.63420	eval-mlogloss:2.29824	train-merror:0.63338	train-mlogloss:2.29562
# [6]	eval-merror:0.63338	eval-mlogloss:2.27418	train-merror:0.63311	train-mlogloss:2.27150
# [7]	eval-merror:0.63336	eval-mlogloss:2.25447	train-merror:0.63249	train-mlogloss:2.25175
# [8]	eval-merror:0.63289	eval-mlogloss:2.23964	train-merror:0.63201	train-mlogloss:2.23670
# [9]	eval-merror:0.63208	eval-mlogloss:2.22768	train-merror:0.63103	train-mlogloss:2.22447

# %%
print('Access logloss metric directly from evals_result:')
print(evals_result['eval']['merror'])

print('')
print('Access metrics through a loop:')
for e_name, e_mtrs in evals_result.items():
    print('- {}'.format(e_name))
    for e_mtr_name, e_mtr_vals in e_mtrs.items():
        print('   - {}'.format(e_mtr_name))
        print('      - {}'.format(e_mtr_vals))

print('')
print('Access complete dictionary:')
print(evals_result)
# Out:
# Access logloss metric directly from evals_result:
# [0.668697, 0.649466, 0.641497, 0.637978, 0.636256, 0.634201, 0.633384, 0.633358, 0.632893, 0.632083]
#
# Access metrics through a loop:
# - eval
#    - merror
#       - [0.668697, 0.649466, 0.641497, 0.637978, 0.636256, 0.634201, 0.633384, 0.633358, 0.632893, 0.632083]
#    - mlogloss
#       - [2.654466, 2.513222, 2.429314, 2.37161, 2.329771, 2.298241, 2.27418, 2.254469, 2.239645, 2.227676]
# - train
#    - merror
#       - [0.667301, 0.649178, 0.64125, 0.636937, 0.635375, 0.633381, 0.633105, 0.632494, 0.632005, 0.631034]
#    - mlogloss
#       - [2.651226, 2.511148, 2.426781, 2.368993, 2.327197, 2.295617, 2.271504, 2.251746, 2.236704, 2.224475]
#
# Access complete dictionary:
# {'eval': {'merror': [0.668697, 0.649466, 0.641497, 0.637978, 0.636256, 0.634201, 0.633384, 0.633358, 0.632893, 0.632083], 'mlogloss': [2.654466, 2.513222, 2.429314, 2.37161, 2.329771, 2.298241, 2.27418, 2.254469, 2.239645, 2.227676]}, 'train': {'merror': [0.667301, 0.649178, 0.64125, 0.636937, 0.635375, 0.633381, 0.633105, 0.632494, 0.632005, 0.631034], 'mlogloss': [2.651226, 2.511148, 2.426781, 2.368993, 2.327197, 2.295617, 2.271504, 2.251746, 2.236704, 2.224475]}}

# %%
fig, ax = plt.subplots(figsize=(12,18))
xgb.plot_importance(model_post, max_num_features=50, height=0.8, ax=ax) #‘weight’ - the number of times a feature is used to split the data across all trees.
plt.show()

# %% [markdown]
# It looks like my merror (multiclass error) as well as the log loss both decreased indicating further rounds are needed before convergence.
#
# Now lets see some predictions and accuracy score.

# %%
pred_le_post = model_post.predict(dvalid_post)
pred_le_post
# Out:
# array([[0.18589756, 0.31532243, 0.02366354, ..., 0.01842751, 0.0097436 ,
#         0.00974677],
#        [0.06648076, 0.09043197, 0.0234676 , ..., 0.03425027, 0.01004306,
#         0.01117614],
#        [0.07998741, 0.10645802, 0.02636645, ..., 0.03627425, 0.00935933,
#         0.00932346],
#        ...,
#        [0.11495259, 0.1534876 , 0.03427752, ..., 0.02388428, 0.00973629,
#         0.00969897],
#        [0.10517827, 0.10098165, 0.03953251, ..., 0.03586563, 0.0092539 ,
#         0.0417733 ],
#        [0.0769433 , 0.1271113 , 0.02437931, ..., 0.02658528, 0.00827744,
#         0.00824571]], dtype=float32)

# %% [markdown]
# Since I picked 'softprob' as the _objective_ in the XGB model, my predictions gave me chance of probabilities class wise. I will need to take the maxium of each row and then convert it back into my class labels.

# %%
temp = pd.DataFrame(pred_le_post)

# %%
preds_le_post = temp.idxmax(axis=1) #takes the max row wise

# %%
pred_post = le.inverse_transform(preds_le_post.astype('int')) #Label Encoder isn't sure how read the numerical numbers so it runs into an error if the type isn't specificed. int36/int64 good too
print(classification_report(y_test_post, pred_post))
print(accuracy_score(y_test_post, pred_post))
# Out:
#               precision    recall  f1-score   support
#
#            A       0.35      0.15      0.21     16104
#            B       0.34      0.59      0.43     24637
#            C       0.55      0.05      0.09      3955
#            D       0.96      0.39      0.55      5204
#            E       0.70      0.20      0.31      6754
#            F       1.00      0.01      0.02      2768
#            G       1.00      0.00      0.00      2161
#            H       0.37      0.05      0.09       865
#            I       0.83      0.05      0.09      2215
#            J       0.83      0.44      0.58      2196
#            K       0.61      0.09      0.16      2263
#            L       0.58      0.04      0.07      4520
#            M       0.68      0.13      0.21      3115
#            N       0.30      0.41      0.35     14274
#            O       0.98      0.29      0.45      7574
#            P       0.21      0.60      0.31     19487
#            Q       0.70      0.01      0.02      3888
#            R       0.60      0.01      0.03      1148
#            S       0.60      0.49      0.54     10143
#            T       0.31      0.09      0.14      6535
#            U       0.31      0.15      0.21       754
#            V       1.00      0.02      0.04       224
#            W       0.92      0.31      0.46      3734
#            X       0.79      0.70      0.74     10444
#            Y       0.87      0.76      0.81      2698
#            Z       0.24      0.08      0.12      1460
#
#     accuracy                           0.37    159120
#    macro avg       0.64      0.24      0.27    159120
# weighted avg       0.52      0.37      0.35    159120
#
# 0.3679172951231775

# %% [markdown]
# Almost 36% accuracy, that is a big improvement! Now lets get a confusion matrix for this dataset then move onto the downsized data set.

# %%
from pandas_ml import ConfusionMatrix
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-43-5a9498c71431> in <module>
# ----> 1 from pandas_ml import ConfusionMatrix
#
# ModuleNotFoundError: No module named 'pandas_ml'

# %%
confusion_matrix = ConfusionMatrix(np.array(y_test_post['NTEE_CD']), pred_post)
print(confusion_matrix)
confusion_matrix.plot()

# %% [markdown]
# Like in the other models, there are handful of classes that seem to contain most of the misclassifications. This gives us some areas to focus into.

# %% [markdown]
# ___

# %% [markdown]
# ### XGB Down

# %% [markdown]
# Running through the same steps we took for the `post` data, lets see what we can get from the roughly equal sized data set.

# %%
le.fit(y_train_down)
list(le.classes_)
y_train_le_down = le.transform(y_train_down.NTEE_CD)
y_test_le_down = le.transform(y_test_down.NTEE_CD)

# %%
dtrain_down = xgb.DMatrix(X_train_down, label=y_train_le_down)
dvalid_down =  xgb.DMatrix(X_test_down, label=y_test_le_down)

# %%
param_down = [('max_depth', 4), ('objective', 'multi:softprob'), ('eval_metric', 'merror'), ('eval_metric', 'mlogloss'), ('num_class', 26)]
 
num_round = 10
watchlist = [(dvalid_down,'eval'), (dtrain_down,'train')]

evals_result = {}
model_down = xgb.train(param_down, dtrain_down, num_round, watchlist, evals_result=evals_result)
# Out:
# [0]	eval-merror:0.71010	eval-mlogloss:2.72233	train-merror:0.70939	train-mlogloss:2.71884
# [1]	eval-merror:0.67898	eval-mlogloss:2.60518	train-merror:0.67704	train-mlogloss:2.60174
# [2]	eval-merror:0.66414	eval-mlogloss:2.53101	train-merror:0.66201	train-mlogloss:2.52702
# [3]	eval-merror:0.65999	eval-mlogloss:2.48100	train-merror:0.65805	train-mlogloss:2.47573
# [4]	eval-merror:0.65654	eval-mlogloss:2.44292	train-merror:0.65467	train-mlogloss:2.43663
# [5]	eval-merror:0.65519	eval-mlogloss:2.41459	train-merror:0.65241	train-mlogloss:2.40761
# [6]	eval-merror:0.65448	eval-mlogloss:2.39130	train-merror:0.65071	train-mlogloss:2.38299
# [7]	eval-merror:0.65288	eval-mlogloss:2.37192	train-merror:0.64876	train-mlogloss:2.36281
# [8]	eval-merror:0.65172	eval-mlogloss:2.35623	train-merror:0.64789	train-mlogloss:2.34633
# [9]	eval-merror:0.65168	eval-mlogloss:2.34334	train-merror:0.64707	train-mlogloss:2.33268

# %%
print('Access logloss metric directly from evals_result:')
print(evals_result['eval']['merror'])

print('')
print('Access metrics through a loop:')
for e_name, e_mtrs in evals_result.items():
    print('- {}'.format(e_name))
    for e_mtr_name, e_mtr_vals in e_mtrs.items():
        print('   - {}'.format(e_mtr_name))
        print('      - {}'.format(e_mtr_vals))

print('')
print('Access complete dictionary:')
print(evals_result)
# Out:
# Access logloss metric directly from evals_result:
# [0.710099, 0.678983, 0.66414, 0.659993, 0.65654, 0.655193, 0.654477, 0.652877, 0.651719, 0.651677]
#
# Access metrics through a loop:
# - eval
#    - merror
#       - [0.710099, 0.678983, 0.66414, 0.659993, 0.65654, 0.655193, 0.654477, 0.652877, 0.651719, 0.651677]
#    - mlogloss
#       - [2.722329, 2.605175, 2.531014, 2.481002, 2.442916, 2.41459, 2.3913, 2.371918, 2.356233, 2.343341]
# - train
#    - merror
#       - [0.709389, 0.677035, 0.662009, 0.658051, 0.654666, 0.652408, 0.650708, 0.648761, 0.647892, 0.647071]
#    - mlogloss
#       - [2.718844, 2.601742, 2.527022, 2.475735, 2.436626, 2.407607, 2.382989, 2.362808, 2.346328, 2.332675]
#
# Access complete dictionary:
# {'eval': {'merror': [0.710099, 0.678983, 0.66414, 0.659993, 0.65654, 0.655193, 0.654477, 0.652877, 0.651719, 0.651677], 'mlogloss': [2.722329, 2.605175, 2.531014, 2.481002, 2.442916, 2.41459, 2.3913, 2.371918, 2.356233, 2.343341]}, 'train': {'merror': [0.709389, 0.677035, 0.662009, 0.658051, 0.654666, 0.652408, 0.650708, 0.648761, 0.647892, 0.647071], 'mlogloss': [2.718844, 2.601742, 2.527022, 2.475735, 2.436626, 2.407607, 2.382989, 2.362808, 2.346328, 2.332675]}}

# %%
pred_le_down = model_down.predict(dvalid_down)
pred_le_down
# Out:
# array([[0.03325973, 0.02371244, 0.04059023, ..., 0.02540436, 0.01039085,
#         0.01196392],
#        [0.01144789, 0.01254568, 0.02325347, ..., 0.00839369, 0.04166441,
#         0.0110006 ],
#        [0.03220398, 0.02160593, 0.03489845, ..., 0.02314754, 0.00946777,
#         0.13049866],
#        ...,
#        [0.01345672, 0.02875133, 0.02120937, ..., 0.0116335 , 0.46500736,
#         0.00777123],
#        [0.0492242 , 0.0305791 , 0.05253293, ..., 0.02225936, 0.01104814,
#         0.01163511],
#        [0.0487951 , 0.03031253, 0.05207499, ..., 0.02206532, 0.01095183,
#         0.01153368]], dtype=float32)

# %%
temp = pd.DataFrame(pred_le_down)

# %%
preds_le_down = temp.idxmax(axis=1)

# %%
pred_down = le.inverse_transform(preds_le_down.astype('int')) #Label Encoder isn't sure how read the numerical numbers so it runs into an error if the type isn't specificed. int36/int64 good too
print(classification_report(y_test_down, pred_down))
print(accuracy_score(y_test_down, pred_down))
# Out:
#               precision    recall  f1-score   support
#
#            A       0.16      0.41      0.23      1994
#            B       0.64      0.40      0.49      1979
#            C       0.56      0.07      0.12      2033
#            D       0.97      0.38      0.55      1941
#            E       0.25      0.27      0.26      1999
#            F       0.15      0.05      0.08      1996
#            G       0.09      0.31      0.14      2038
#            H       0.53      0.05      0.09       948
#            I       0.20      0.09      0.12      1970
#            J       0.74      0.66      0.70      1929
#            K       0.74      0.24      0.36      1908
#            L       0.18      0.38      0.25      1964
#            M       0.25      0.21      0.23      2020
#            N       0.28      0.43      0.34      1991
#            O       0.87      0.30      0.45      1944
#            P       0.09      0.12      0.10      2015
#            Q       0.76      0.29      0.42      2085
#            R       0.53      0.42      0.47      1988
#            S       0.59      0.39      0.47      2022
#            T       0.32      0.15      0.20      2010
#            U       0.37      0.23      0.29       849
#            V       0.86      0.02      0.04       263
#            W       0.83      0.67      0.74      2099
#            X       0.72      0.66      0.69      1970
#            Y       0.78      0.80      0.79      2013
#            Z       0.20      0.60      0.30      1531
#
#     accuracy                           0.35     47499
#    macro avg       0.49      0.33      0.34     47499
# weighted avg       0.48      0.35      0.36     47499
#
# 0.34832312259205456

# %% [markdown]
# 33.5% considerbly lower than the `post` data. Taking a look at the merror and the logloss metrics, they also decreased but at much larger steps than the `post` data. With these parameters, this model would only increase with more rounds run.

# %%
from pandas_ml import ConfusionMatrix

# %%
confusion_matrix = ConfusionMatrix(np.array(y_test_down['NTEE_CD']), pred_down)
print(confusion_matrix)
confusion_matrix.plot()
# Out:
# Predicted     A     B    C    D    E     F     G   H     I     J   ...     \
# Actual                                                             ...
# A           719    48    0    0    7    69   335   0   109    15   ...
# B           342   758    0    0   19    34   172   1    33    22   ...
# C           346    53   97    4   11    50   314   3   139    10   ...
# D           106     5    0  735    6    38   296   1    58     2   ...
# E           119    31    1    2  376   109   199   7    69    57   ...
# F           265    12    0    1   34   185   439   2    69     2   ...
# G           268     7    1    0   21    47   481   9    59     7   ...
# H            98     3    0    1   40    13   191  44    42     1   ...
# I           194     7    0    2    7    92   385   0   236    19   ...
# J           116    77    3    0    5    28    35   1    36  1235   ...
# K           145    18    0    4    5    36   251   0    45    28   ...
# L            50    12    0    0   15    44   175   0    58     3   ...
# M           175     9    0    1    2    38   355   1   101     3   ...
# N           253    37    1    0    5    26   297   0    36     1   ...
# O           279    50    0    3   14    46   320   0    54     3   ...
# P           135    17    0    1   18   119   436   0    84     0   ...
# Q           138    14    1    1   10    31   318   0    38     1   ...
# R           218    12    0    0    7    45   161   1    42    59   ...
# S           134     8    0    2    7    36   213   0    73    52   ...
# T            74    11    0    2   27   108   279   0   131     5   ...
# U           234    12    2    1    6    21    97  16    29    14   ...
# V            88     7    0    0    1     5    26   0     8     2   ...
# W            63     7    1    1    5    10    82   2    13    39   ...
# X            43    26    0    0   13    20   115   0    52     7   ...
# Y             6    27    0    0    1     5    12   0     0    49   ...
# Z            92    11    0    5    3    29    81   1    40     9   ...
# __all__    4700  1279  107  766  665  1284  6065  89  1654  1645   ...
#
# Predicted     R     S     T    U  V     W     X     Y     Z  __all__
# Actual
# A            21    14    64    7  0     0    16    11   159     1973
# B            18    10    55   12  2     9    18   131    70     1969
# C            57    43    60   61  2     5     1     7   217     1965
# D             2    29    28   18  0     0     6     0   158     2044
# E             7    34   148   20  0     7    20    17   168     1986
# F             7    11    41   11  0     0    73     0   194     2058
# G             9    31    25   48  0     1     8     0   188     2002
# H             6    11    22   83  0     0     4     0    78      920
# I            22    43    36    6  0     1    40     9   246     1997
# J            47    21    28    4  0    28     2    21    34     1893
# K            23    24    22   10  0     6    23    44   145     1939
# L            73    73    91    0  0     1    37     4   232     1947
# M             8    39    32    6  0     6     8     3   198     2022
# N            49    48    36    3  1    11     6    38   119     1951
# O            10     5    48    5  0     3    36    17   176     2051
# P            16    13    38    2  0     5    73     1   200     2030
# Q            28    16    12    5  0     4    49     2   151     2020
# R           818   124    25    2  0    23    11     4   119     2007
# S            20   817    34    5  0    10    11    22   181     2052
# T            27    19   322    3  0     7    25    59   249     2057
# U             5    37    16  211  0     0     2     0    63      891
# V             8     5     5   23  3     1     1     0    19      251
# W            79    29     9    4  0  1181     9    93    59     1949
# X             2     2    37    0  0    10  1330     5    85     1968
# Y            31    35    20    0  0    69     4  1625    20     2062
# Z            11    38    31    4  0     5    33    12   832     1495
# __all__    1404  1571  1285  553  8  1393  1846  2125  4360    47499
#
# [27 rows x 27 columns]

# %%
import pickle

# %%
# save model to file
pickle.dump(model_post, open("./models/post_xgb.pickle.dat", "wb"))
# save model to file
pickle.dump(model_down, open("./models/down_xgb.pickle.dat", "wb"))

# Later you can load this file to deserialize your model and use it to make new predictions, for example:
# # load model from file
# #loaded_model = pickle.load(open("pima.pickle.dat", "rb"))
# 1
# 2
	
# # load model from file
# loaded_model = pickle.load(open("pima.pickle.dat", "rb"))

# %% [markdown]
# # Results

# %%
results
# Out:
# {'DecisionTree': {'Full': {'FitTime': 218.92935371398926,
#    'Accuracy': 21.89090217339611},
#   'Post': {'FitTime': 58.23425626754761, 'Accuracy': 20.934514831573654},
#   'Down': {'FitTime': 5.247431755065918, 'Accuracy': 12.452893745131476}},
#  'RandomForest': {'Full': {'FitTime': 609.259092092514,
#    'Accuracy': 31.354884315153924},
#   'Post': {'FitTime': 271.7068748474121, 'Accuracy': 32.18314594737272},
#   'Down': {'FitTime': 48.1766095161438, 'Accuracy': 28.80948245461675}},
#  'XGB': {'Full': {}, 'Post': {}, 'Down': {}}}

# %%
results['DecisionTree']
# Out:
# {'Full': {'FitTime': 218.92935371398926, 'Accuracy': 21.89090217339611},
#  'Post': {'FitTime': 58.23425626754761, 'Accuracy': 20.934514831573654},
#  'Down': {'FitTime': 5.247431755065918, 'Accuracy': 12.452893745131476}}

# %%
results['RandomForest']
# Out:
# {'Full': {'FitTime': 609.259092092514, 'Accuracy': 31.354884315153924},
#  'Post': {'FitTime': 271.7068748474121, 'Accuracy': 32.18314594737272},
#  'Down': {'FitTime': 48.1766095161438, 'Accuracy': 28.80948245461675}}

# %%
results['XGB']
# Out:
# {'Full': {}, 'Post': {}, 'Down': {}}

# %% [markdown]
# Now let quickly make a CDF for my highest accuracy. Ideally this would be used for at least 2 years, lets see the effectiveness of it

# %%
p = .37
q = 1 - p
result = []

for year in list(range(0,10)):
    chance = (q**year)*(p)
    result.append(chance)
    print(f'Given a wrong Major Group, Chance of flagging at the end of {year + 1} years: {round(sum(result), 4)}%')


cumulative = np.cumsum(result)

plt.plot(list(range(0,10)), cumulative, c='blue')
plt.title('CDF')
plt.xticks(list(range(0,10)))
plt.xlabel('Cumulative Years')
plt.ylabel('Percent of flagging for audit')
plt.yticks(np.linspace(0, 1, 11))
plt.show()
# Out:
# Given a wrong Major Group, Chance of flagging at the end of 1 years: 0.37%
# Given a wrong Major Group, Chance of flagging at the end of 2 years: 0.6031%
# Given a wrong Major Group, Chance of flagging at the end of 3 years: 0.75%
# Given a wrong Major Group, Chance of flagging at the end of 4 years: 0.8425%
# Given a wrong Major Group, Chance of flagging at the end of 5 years: 0.9008%
# Given a wrong Major Group, Chance of flagging at the end of 6 years: 0.9375%
# Given a wrong Major Group, Chance of flagging at the end of 7 years: 0.9606%
# Given a wrong Major Group, Chance of flagging at the end of 8 years: 0.9752%
# Given a wrong Major Group, Chance of flagging at the end of 9 years: 0.9844%
# Given a wrong Major Group, Chance of flagging at the end of 10 years: 0.9902%
